# %% [markdown]
# <a href="https://colab.research.google.com/github/Saanvi-U/Pneumonia-Detection-AlexNet/blob/main/Alexnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow numpy matplotlib seaborn scikit-learn kagglehub

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

import kagglehub

# Download dataset
path = kagglehub.dataset_download("paultimothymooney/chest-xray-pneumonia")

# Set directory paths
base_dir = '/kaggle/input/chest-xray-pneumonia/chest_xray'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

# Function to count images
def count_images(directory):
    return {
        'NORMAL': len(os.listdir(os.path.join(directory, 'NORMAL'))),
        'PNEUMONIA': len(os.listdir(os.path.join(directory, 'PNEUMONIA')))
    }

# Count images
train_counts = count_images(train_dir)

# Plot distribution
sns.barplot(x=list(train_counts.keys()), y=list(train_counts.values()))
plt.title("Training Set Distribution")
plt.show()

# Compute class weights
labels = [0] * train_counts['NORMAL'] + [1] * train_counts['PNEUMONIA']
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(labels), y=labels)
class_weights = dict(enumerate(class_weights))
print("Class weights:", class_weights)

# Image parameters
IMAGE_SIZE = (227, 227)   # Fixed to 227x227 as per AlexNet
BATCH_SIZE = 32

# Data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary'
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary'
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False
)

# Build AlexNet model
def build_alexnet(input_shape=(227, 227, 3)):
    model = Sequential([
        # Layer 1
        Conv2D(96, (11, 11), strides=4, activation='relu', input_shape=input_shape),
        BatchNormalization(),
        MaxPooling2D((3, 3), strides=2),

        # Layer 2
        Conv2D(256, (5, 5), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D((3, 3), strides=2),

        # Layer 3
        Conv2D(384, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),

        # Layer 4
        Conv2D(384, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),

        # Layer 5
        Conv2D(256, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D((3, 3), strides=2),

        # Flatten
        Flatten(),

        # Fully connected layers
        Dense(4096, activation='relu', kernel_regularizer=l2(0.01)),
        Dropout(0.5),

        Dense(4096, activation='relu', kernel_regularizer=l2(0.01)),
        Dropout(0.5),

        # Output layer
        Dense(1, activation='sigmoid')
    ])
    return model

# Compile model
model = build_alexnet()
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()

# Train model
def train_model(model, epochs=10):
    print("\nTraining model...")
    history = model.fit(
        train_generator,
        epochs=epochs,
        validation_data=val_generator,
        class_weight=class_weights
    )
    return history

# Plot training history
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.figure(figsize=(14,5))

    plt.subplot(1,2,1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend()
    plt.title('Accuracy')

    plt.subplot(1,2,2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend()
    plt.title('Loss')

    plt.show()

# Evaluate model
def evaluate_model(model):
    test_loss, test_acc = model.evaluate(test_generator)
    print(f"\nTest Accuracy: {test_acc:.2f} - Loss: {test_loss:.2f}")

    y_true = test_generator.classes
    y_pred = model.predict(test_generator)
    y_pred_labels = (y_pred > 0.5).astype(int).flatten()

    print("\nClassification Report:\n")
    print(classification_report(y_true, y_pred_labels, target_names=["NORMAL", "PNEUMONIA"]))

    cm = confusion_matrix(y_true, y_pred_labels)
    sns.heatmap(cm, annot=True, fmt="d", cmap='Blues',
                xticklabels=["NORMAL", "PNEUMONIA"],
                yticklabels=["NORMAL", "PNEUMONIA"])
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    # Sensitivity, Specificity
    TN, FP, FN, TP = cm.ravel()
    sensitivity = TP / (TP + FN)
    specificity = TN / (TN + FP)
    accuracy = (TP + TN) / (TP + TN + FP + FN)

    print(f"Sensitivity (Recall for PNEUMONIA): {sensitivity:.4f}")
    print(f"Specificity (Recall for NORMAL): {specificity:.4f}")
    print(f"Overall Accuracy: {accuracy:.4f}")

# Main pipeline
initial_epochs = 10  # or 15 based on performance
history = train_model(model, epochs=initial_epochs)
plot_history(history)
evaluate_model(model)

# Save model
model.save("pneumonia_alexnet.h5")
print("\nModel saved as pneumonia_alexnet.h5")
# Out:
# Class weights: {0: np.float64(1.9448173005219984), 1: np.float64(0.6730322580645162)}
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 55, 55, 96)     │        34,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.save('/content/drive/MyDrive/pneumonia_alexnet.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model

# Load the model
loaded_model = load_model('pneumonia_alexnet.h5')

# Test on one image (optional check)
sample = test_generator[0][0][0]  # First image of first batch
sample = np.expand_dims(sample, axis=0)  # Add batch dimension
prediction = loaded_model.predict(sample)
print(f"Predicted Probability of Pneumonia: {prediction[0][0]:.4f}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# Predicted Probability of Pneumonia: 0.4319

# %%
# Pick a random sample from the test generator
import numpy as np
import matplotlib.pyplot as plt

# Get a batch of images and labels
images, labels = next(test_generator)

# Pick a random index
random_index = np.random.randint(0, images.shape[0])

# Get the image and true label
sample_image = images[random_index]
true_label = labels[random_index]

# Prepare image for prediction (model expects batch dimension)
sample_image_batch = np.expand_dims(sample_image, axis=0)

# Predict
prediction = loaded_model.predict(sample_image_batch)
predicted_prob = prediction[0][0]

# Display
plt.imshow(sample_image)
plt.axis('off')
plt.title(f"True Label: {'Pneumonia' if true_label==1 else 'Normal'}\nPredicted Prob: {predicted_prob:.4f}")
plt.show()

# Prediction Decision
if predicted_prob > 0.5:
    print("Model Prediction: Pneumonia")
else:
    print("Model Prediction: Normal")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Model Prediction: Normal

# %%
import numpy as np
import matplotlib.pyplot as plt

# Get a batch of images and labels
images, labels = next(test_generator)

# Number of random samples you want
num_samples = 5

# Random indices
random_indices = np.random.choice(images.shape[0], size=num_samples, replace=False)

# Set up the plot
plt.figure(figsize=(15, 5))

for i, idx in enumerate(random_indices):
    sample_image = images[idx]
    true_label = labels[idx]

    # Prepare for prediction
    sample_image_batch = np.expand_dims(sample_image, axis=0)

    # Predict
    prediction = loaded_model.predict(sample_image_batch)
    predicted_prob = prediction[0][0]

    # Plot
    plt.subplot(1, num_samples, i + 1)
    plt.imshow(sample_image)
    plt.axis('off')
    plt.title(f"True: {'Pneumonia' if true_label==1 else 'Normal'}\nPred: {predicted_prob:.2f}")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step

# %%
print(prediction)
print("True Label:", true_label)
# Out:
# [[0.11070238]]
# True Label: 0.0

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model

# Assuming the model is already trained and saved
model = load_model("pneumonia_alexnet.h5")

# Directory paths
base_dir = '/kaggle/input/chest-xray-pneumonia/chest_xray'
test_dir = os.path.join(base_dir, 'test')

# Test generator (same size and preprocessing as during training)
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(227, 227),  # Same size as the model input
    batch_size=32,
    class_mode='binary',
    shuffle=False  # We want to predict the exact order of files
)

# Predict for all images in the test set
def display_images_with_predictions(test_generator, threshold=0.5):
    """
    Function to display images with their predicted labels.
    """
    true_labels = test_generator.classes  # True labels from the generator
    filenames = test_generator.filenames  # Get filenames for reference
    probabilities = []  # Predicted probabilities

    # Get predictions
    predictions = model.predict(test_generator, verbose=1)
    for prob in predictions:
        probabilities.append(prob[0])  # Append predicted probability

    # Display images with their predictions
    plt.figure(figsize=(15, 15))
    for i, (filename, prob) in enumerate(zip(filenames, probabilities)):
        plt.subplot(8, 8, i+1)  # Adjust rows and columns if needed
        img_path = os.path.join(test_dir, filename)
        img = plt.imread(img_path)

        plt.imshow(img)
        plt.axis('off')
        label = 'Pneumonia' if prob > threshold else 'Normal'
        plt.title(f"{label} ({prob:.2f})")

    plt.tight_layout()
    plt.show()

# Display images with predictions
display_images_with_predictions(test_generator, threshold=0.5)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Found 624 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 901ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d595dce81558> in <cell line: 0>()
#      54
#      55 # Display images with predictions
# ---> 56 display_images_with_predictions(test_generator, threshold=0.5)
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the table
networks = ['ResNet', 'AlexNet']
metrics = ['Accuracy', 'Sensitivity', 'Specificity']
values = np.array([
    [79, 80, 76],  # ResNet values
    [72, 99, 27]   # AlexNet values
])

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Set width of bars
bar_width = 0.35

# Set position of bars on X axis
r1 = np.arange(len(metrics))
r2 = [x + bar_width for x in r1]

# Create bars
bars1 = ax.bar(r1, values[0], bar_width, label='ResNet', color='#1f77b4', alpha=0.8)
bars2 = ax.bar(r2, values[1], bar_width, label='AlexNet', color='#ff7f0e', alpha=0.8)

# Add labels and title
ax.set_xlabel('Metrics', fontweight='bold', fontsize=14)
ax.set_ylabel('Percentage (%)', fontweight='bold', fontsize=14)
ax.set_title('ResNet vs AlexNet Comparison', fontweight='bold', fontsize=16)
ax.set_xticks([r + bar_width/2 for r in range(len(metrics))])
ax.set_xticklabels(metrics, fontsize=12)
ax.set_ylim(0, 110)  # Set y-limit to accommodate all values with some headroom

# Add value labels on top of bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height}%',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', fontweight='bold')

add_labels(bars1)
add_labels(bars2)

# Add legend
ax.legend(fontsize=12)

# Add a grid for better readability
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Add text for additional information
plt.figtext(0.5, 0.01,
           "Additional Comparisons:\n" +
           "• ResNet: Deep CNN with Residual Blocks, better for complex medical tasks, longer training time\n" +
           "• AlexNet: Classic CNN with sequential layers, suitable for moderate complexity tasks, faster training",
           ha="center", fontsize=10, bbox={"facecolor":"white", "alpha":0.5, "pad":5})

plt.tight_layout(rect=[0, 0.05, 1, 0.95])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# Data from the table
categories = ['Accuracy', 'Sensitivity', 'Specificity',
              'Complex Task\nSuitability', 'Training\nSpeed']

# Values for each category (0-100 scale)
# For non-percentage metrics, using relative scale where higher = better
resnet_values = [79, 80, 76, 90, 40]  # ResNet with high complex task score, low training speed
alexnet_values = [72, 99, 27, 60, 80]  # AlexNet with moderate task score, high training speed

# Calculate angles for each category
N = len(categories)
angles = [n / float(N) * 2 * np.pi for n in range(N)]
angles += angles[:1]  # Close the loop

# Add the values for the loop closure
resnet_values += resnet_values[:1]
alexnet_values += alexnet_values[:1]

# Set up the figure
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw=dict(polar=True))

# Plot the values
ax.plot(angles, resnet_values, 'o-', linewidth=2, label='ResNet', color='#1f77b4')
ax.fill(angles, resnet_values, alpha=0.25, color='#1f77b4')
ax.plot(angles, alexnet_values, 'o-', linewidth=2, label='AlexNet', color='#ff7f0e')
ax.fill(angles, alexnet_values, alpha=0.25, color='#ff7f0e')

# Set category labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontsize=12)

# Add value labels
for i, value in enumerate(resnet_values[:-1]):
    angle_rad = angles[i]
    if angle_rad <= np.pi/2 or angle_rad >= 3*np.pi/2:
        ha = 'left'
    else:
        ha = 'right'
    ax.annotate(f"{value}",
                xy=(angle_rad, value + 2),
                xytext=(angle_rad, value + 8),
                ha=ha,
                color='#1f77b4',
                fontweight='bold')

for i, value in enumerate(alexnet_values[:-1]):
    angle_rad = angles[i]
    if angle_rad <= np.pi/2 or angle_rad >= 3*np.pi/2:
        ha = 'left'
    else:
        ha = 'right'
    ax.annotate(f"{value}",
                xy=(angle_rad, value + 2),
                xytext=(angle_rad, value + 8),
                ha=ha,
                color='#ff7f0e',
                fontweight='bold')

# Set chart limits and grid
ax.set_ylim(0, 100)
ax.set_yticks(np.arange(0, 101, 20))
ax.set_yticklabels([f"{x}%" for x in range(0, 101, 20)], fontsize=10)
ax.grid(True, linestyle='--', alpha=0.7)

# Add a title
plt.title('ResNet vs AlexNet Performance Comparison', size=16, fontweight='bold', y=1.1)

# Create custom legend
resnet_patch = mpatches.Patch(color='#1f77b4', alpha=0.5, label='ResNet (Deep CNN with Residual Blocks)')
alexnet_patch = mpatches.Patch(color='#ff7f0e', alpha=0.5, label='AlexNet (Classic CNN with sequential layers)')
plt.legend(handles=[resnet_patch, alexnet_patch], loc='upper right', bbox_to_anchor=(0.1, 1.1))

# Add text box with additional information
textbox = """Key Insights:
• ResNet shows balanced performance across accuracy metrics
• AlexNet has exceptional sensitivity (99%) but poor specificity (27%)
• ResNet better suited for complex medical diagnosis tasks
• AlexNet offers faster training with its simpler architecture"""

props = dict(boxstyle='round', facecolor='white', alpha=0.7)
plt.figtext(0.5, 0.02, textbox, fontsize=10, ha='center',
           bbox=props)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

# Bar chart showing key performance metrics
metrics = ['Accuracy', 'Sensitivity', 'Specificity']
resnet_values = [79, 80, 76]
alexnet_values = [72, 99, 27]

x = np.arange(len(metrics))
width = 0.35

# Create bar chart
bars1 = ax1.bar(x - width/2, resnet_values, width, label='ResNet', color='#1f77b4')
bars2 = ax1.bar(x + width/2, alexnet_values, width, label='AlexNet', color='#ff7f0e')

# Add labels and formatting
ax1.set_title('Performance Metrics', fontsize=11, fontweight='bold')
ax1.set_xticks(x)
ax1.set_xticklabels(metrics, fontsize=9)
ax1.set_ylim(0, 110)
ax1.set_ylabel('Percentage (%)')
ax1.grid(axis='y', linestyle='--', alpha=0.5)

# Add value labels on bars
for bar in bars1:
    height = bar.get_height()
    ax1.annotate(f'{height}%', xy=(bar.get_x() + bar.get_width()/2, height),
                xytext=(0, 3), textcoords="offset points",
                ha='center', va='bottom', fontsize=8, fontweight='bold')

for bar in bars2:
    height = bar.get_height()
    ax1.annotate(f'{height}%', xy=(bar.get_x() + bar.get_width()/2, height),
                xytext=(0, 3), textcoords="offset points",
                ha='center', va='bottom', fontsize=8, fontweight='bold')

# Hide axis for table subplot
ax2.axis('off')
ax2.set_title('Architectural Comparison', fontsize=11, fontweight='bold')

# Create comparison data
categories = ['Architecture', 'Best For', 'Training']
resnet_data = ['Deep with\nResidual Blocks', 'Complex\nMedical Tasks', 'Longer']
alexnet_data = ['Classic\nSequential', 'Moderate\nComplexity', 'Faster']
cell_colors = [['#d0e7f7', '#ffffff'], ['#d0e7f7', '#ffffff'], ['#ffffff', '#ffecd0']]

# Create table with custom coloring
the_table = ax2.table(
    cellText=[resnet_data, alexnet_data],
    rowLabels=['ResNet', 'AlexNet'],
    colLabels=categories,
    loc='center',
    cellLoc='center',
    cellColours=list(zip(*cell_colors)),  # Transpose to match table structure
    rowColours=['#f0f0f0', '#f0f0f0'],
    colColours=['#f0f0f0', '#f0f0f0', '#f0f0f0']
)

# Style the table
the_table.auto_set_font_size(False)
the_table.set_fontsize(7)
the_table.scale(2, 2)

# Add a title and the conclusion
fig.suptitle('ResNet vs AlexNet: Performance Trade-offs', fontsize=12, fontweight='bold')

# Add legend for the bar chart
ax1.legend(loc='upper right', fontsize=8)

# Add result findings with winner indicators
conclusion = """RESULTS: ResNet outperforms AlexNet with higher accuracy (+7%) and much better
specificity (+49%), making it superior for complex medical tasks despite longer
training times. AlexNet excels in sensitivity (+19%) and training speed only."""

fig.text(0.5, 0.04, conclusion, ha='center', fontsize=8,
         bbox=dict(facecolor='#f5f5f5', alpha=0.8, boxstyle='round,pad=0.5'))

plt.tight_layout()
plt.subplots_adjust(bottom=0.22)
plt.show()
